# %% [markdown]
# Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sklearn modules for splitting, scaling, and models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Ensures plots are shown inline in Jupyter Notebooks
# %matplotlib inline

# %%
# Load the dataset xls files
dataset = pd.read_excel('diabetes.xls')

# View the basic information (columns, non-null counts, data types)
print("--- Dataset Info ---")
dataset.info()

# Check for explicit missing (null) values
print("\n--- Missing Values Check ---")
print(dataset.isnull().sum())

# Generate descriptive statistics (mean, std, min, max, quartiles)
print("\n--- Descriptive Statistics ---")
print(dataset.describe())
